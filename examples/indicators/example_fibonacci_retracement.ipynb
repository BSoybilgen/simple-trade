# %%
# Load functions
from simple_trade import download_data
from simple_trade import calculate_fibonacci_levels, plot_fibonacci_retracement

# %%
# Download data
symbol = 'TSLA'
start = '2024-01-01'
end = '2025-01-01'
interval = '1d'
print(f"\nDownloading data for {symbol}...")
data = download_data(symbol, start, end, interval=interval)
data = data['Close']
# Out:
# Downloading data for TSLA...

# %%
# Calculate Fibonacci retracement levels
fibo = calculate_fibonacci_levels(data)

# %%
# Example of using the fibonacci retracement tool
plot_fibonacci_retracement(data)
