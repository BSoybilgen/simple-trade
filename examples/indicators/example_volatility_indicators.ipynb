# %% [markdown]
# ### Load Functions

# %%
from simple_trade import compute_indicator, download_data
import pandas as pd
from simple_trade import IndicatorPlotter

# Set pandas display options for better output
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# Create a plotter instance
plotter = IndicatorPlotter()

# %% [markdown]
# ### The Average True Range (ATR)

# %%
# Step 1: Download data
symbol = 'GOOG'
start = '2024-01-01'
interval = '1d'
print(f"\nDownloading data for {symbol}...")
data = download_data(symbol, start, interval=interval)

# Step 2: Calculate indicator
data = compute_indicator(
    data=data,
    indicator='atr',
    window=14,
)

# Step 3: Plot the indicator
columns = ['ATR_14']
fig = plotter.plot_results(
        data,
        price_col='Close',
        column_names=columns,
        plot_on_subplot=True, 
        title=f"{symbol} with ATR_14"
    )
# Out:
# Downloading data for GOOG...
# Computing ATR...

# %% [markdown]
# ### The Bollinger Bands (BOLLIN)

# %%
# Step 1: Download data
symbol = 'GOOG'
start = '2024-01-01'
interval = '1d'
print(f"\nDownloading data for {symbol}...")
data = download_data(symbol, start, interval=interval)

# Step 2: Calculate indicator
data = compute_indicator(
    data=data,
    indicator='bollin',
    window=20,
    num_std=2,
)

# Step 3: Plot the indicator
columns = ['BB_Middle_20', 'BB_Upper_20_2', 'BB_Lower_20_2']
fig = plotter.plot_results(
        data,
        price_col='Close',
        column_names=columns,
        plot_on_subplot=False, 
        title=f"{symbol} with Bollinger_20"
    )
# Out:
# Downloading data for GOOG...
# Computing BOLLIN...

# %% [markdown]
# ### The Chaikin Volatility (CHAIK)

# %%
# Step 1: Download data
symbol = 'GOOG'
start = '2024-01-01'
interval = '1d'
print(f"\nDownloading data for {symbol}...")
data = download_data(symbol, start, interval=interval)

# Step 2: Calculate indicator
data = compute_indicator(
    data=data,
    indicator='chaik',
    ema_window=10,
    roc_window=10,
)

# Step 3: Plot the indicator
columns = ['CHAIK_10_10']
fig = plotter.plot_results(
        data,
        price_col='Close',
        column_names=columns,
        plot_on_subplot=True, 
        title=f"{symbol} with CHAIK_10_10"
    )
# Out:
# Downloading data for GOOG...
# Computing CHAIK...

# %% [markdown]
# ### The Donchian Channels (DONCH)

# %%
# Step 1: Download data
symbol = 'GOOG'
start = '2024-01-01'
interval = '1d'
print(f"\nDownloading data for {symbol}...")
data = download_data(symbol, start, interval=interval)

# Step 2: Calculate indicator
data = compute_indicator(
    data=data,
    indicator='donch',
    window=20,
)

# Step 3: Plot the indicator
columns = ['DONCH_Upper_20', 'DONCH_Middle_20', 'DONCH_Lower_20']
fig = plotter.plot_results(
        data,
        price_col='Close',
        column_names=columns,
        plot_on_subplot=False, 
        title=f"{symbol} with DONCH_20"
    )
# Out:
# Downloading data for GOOG...
# Computing DONCH...

# %% [markdown]
# ### The Keltner Channels (KELT)

# %%
# Step 1: Download data
symbol = 'GOOG'
start = '2024-01-01'
interval = '1d'
print(f"\nDownloading data for {symbol}...")
data = download_data(symbol, start, interval=interval)

# Step 2: Calculate indicator
data = compute_indicator(
    data=data,
    indicator='kelt',
    ema_window=20, 
    atr_window=10, 
    atr_multiplier=2.0,
)

# Step 3: Plot the indicator
columns = ['KELT_Middle_20', 'KELT_Upper_20', 'KELT_Lower_20']
fig = plotter.plot_results(
        data,
        price_col='Close',
        column_names=columns,
        plot_on_subplot=False, 
        title=f"{symbol} with KELT_20"
    )
# Out:
# Downloading data for GOOG...
# Computing KELT...
