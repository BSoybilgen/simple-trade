# %%
# Load functions
from simple_trade import download_data, find_resistance_support_lines, plot_resistance_support

# %%
# Download data
symbol = 'TSLA'
start = '2024-01-01'
end = '2025-01-01'
interval = '1d'
print(f"\nDownloading data for {symbol}...")
data = download_data(symbol, start, end, interval=interval)
data = data['Close']

# %%
# Example of resistance and support lines
# Find resistance and support lines
resistance_lines, support_lines, pivots = find_resistance_support_lines(data)

# Plot the price data and resistance/support lines
plot_resistance_support(data)
